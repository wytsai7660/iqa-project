# %% [markdown]
# # Sequential Multi-Task IQA Training Pipeline
#
# This notebook trains three tasks sequentially:
# 1. **Stage 1**: Scene Classification
# 2. **Stage 2**: Distortion Classification (building on Scene knowledge)
# 3. **Stage 3**: Quality Assessment (building on Scene + Distortion knowledge)
#
# Each stage is in a separate cell, so if one fails, you can fix it and continue from that stage.

# %% [markdown]
# ## Configuration

# %%
# Configuration parameters
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Training configuration
DATASET_PATHS = ["datasets/koniq-10k/"]  # Change to your dataset
OUTPUT_DIR = "outputs/10281300"
BASE_MODEL = "src/owl3"

# Training hyperparameters
MAX_STEPS = -1  # Number of steps per stage (-1 for full epochs)
NUM_TRAIN_EPOCHS = 3
BATCH_SIZE = 1
GRAD_ACCUM = 8
LEARNING_RATE = 2e-4
EVAL_STEPS = 100
SAVE_STEPS = 100
LOGGING_STEPS = 50

# Early stopping configuration
EARLY_STOPPING_PATIENCE = 5  # Stop if no improvement after 5 evaluations

# LoRA parameters
LORA_R = 16
LORA_ALPHA = 32
LORA_DROPOUT = 0.05

# Loss weights
USE_FIDELITY_LOSS = True

print("✅ Configuration set!")
print(f"📁 Dataset: {DATASET_PATHS}")
print(f"📁 Output: {OUTPUT_DIR}")
print(f"🎯 Training: {NUM_TRAIN_EPOCHS} epochs, max {MAX_STEPS} steps per stage")
print(f"⚙️  Batch Size: {BATCH_SIZE} × {GRAD_ACCUM} = {BATCH_SIZE * GRAD_ACCUM}")
print(f"🛑 Early Stopping: patience={EARLY_STOPPING_PATIENCE} (stop if no improvement after {EARLY_STOPPING_PATIENCE} evaluations)")
# Out:
# ✅ Configuration set!
# 📁 Dataset: ['datasets/koniq-10k/']
# 📁 Output: outputs/10270900
# 🎯 Training: 3 epochs, max -1 steps per stage
# ⚙️  Batch Size: 1 × 8 = 8
# 🛑 Early Stopping: patience=5 (stop if no improvement after 5 evaluations)

# %% [markdown]
# ## Imports and Setup

# %%
import sys
from pathlib import Path
import torch

from transformers import (
    AutoTokenizer,
    TrainingArguments,
    set_seed,
)

# Add src to path
sys.path.insert(0, str(Path.cwd()))

from src.new_train.model_wrapper import IQAModelWrapper
from src.new_train.dataset_adapter import IQAPairDataset, collate_fn_pair
from src.new_train.processor_no_cut import create_processor_no_cut
from src.new_train.iqa_trainer import IQATrainer
from src.new_train.plot_utils import plot_training_curves

# Import collate functions
from src.new_train.train_scene import collate_fn_scene
from src.new_train.train_distortion import collate_fn_distortion

# Set seed
set_seed(42)

print("✅ Imports completed!")
# Out:
# ✅ Imports completed!

# %% [markdown]
# ## Initialize Model (Run Once)

# %%
# Create output directory
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)

print("🔧 Loading tokenizer and processor...")
tokenizer = AutoTokenizer.from_pretrained(
    BASE_MODEL,
    trust_remote_code=True,
)
processor = create_processor_no_cut(tokenizer)

print("🔧 Initializing model with LoRA...")
model = IQAModelWrapper(
    model_name_or_path=BASE_MODEL,
    lora_r=LORA_R,
    lora_alpha=LORA_ALPHA,
    lora_dropout=LORA_DROPOUT,
    weight_fidelity=1.0 if USE_FIDELITY_LOSS else 0.0,
)

print("\n✅ Model initialized!")
print(f"📊 Model will be trained sequentially on 3 tasks")
# Out:
# 🔧 Loading tokenizer and processor...
# 🔧 Initializing model with LoRA...
# use flash_attn rotary
# HyperQwen2ForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# trainable params: 43,356,160 || all params: 8,115,903,040 || trainable%: 0.5342
#
# ✅ Model initialized!
# 📊 Model will be trained sequentially on 3 tasks

# %% [markdown]
# ---
# ## Stage 1: Scene Classification Training
#
# Train the model to classify scene types (e.g., landscape, cityscape, human, etc.)

# %%
print("="*80)
print("STAGE 1/3: Scene Classification Training")
print("="*80)

# Create dataset
print("\n📊 Creating scene classification dataset...")
dataset_paths = [Path(p) for p in DATASET_PATHS]
train_dataset_scene = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="training",
    use_scene_labels=True,
    use_distortion_labels=False,
)

val_dataset_scene = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="validation",
    use_scene_labels=True,
    use_distortion_labels=False,
)

print(f"✅ Training dataset size: {len(train_dataset_scene)}")
print(f"✅ Validation dataset size: {len(val_dataset_scene)}")
# Out:
# ================================================================================
# STAGE 1/3: Scene Classification Training
# ================================================================================
#
# 📊 Creating scene classification dataset...
# ✅ Training dataset size: 7252
# ✅ Validation dataset size: 1813

# %%
# Training arguments for Scene task
output_dir_scene = f"{OUTPUT_DIR}/01_scene"
training_args_scene = TrainingArguments(
    output_dir=output_dir_scene,
    num_train_epochs=NUM_TRAIN_EPOCHS if MAX_STEPS <= 0 else 1,
    max_steps=MAX_STEPS if MAX_STEPS > 0 else -1,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRAD_ACCUM,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type="cosine",
    warmup_ratio=0.03,
    weight_decay=0.0,
    logging_steps=LOGGING_STEPS,
    eval_strategy="steps",
    eval_steps=EVAL_STEPS,
    save_strategy="steps",
    save_steps=SAVE_STEPS,
    save_total_limit=2,
    bf16=True,
    dataloader_num_workers=12,
    remove_unused_columns=False,
    report_to="none",
    load_best_model_at_end=True,  # Load best model based on eval_loss
    metric_for_best_model="eval_loss",
    greater_is_better=False,  # Lower loss is better
)

print("✅ Training arguments configured for Scene task")
print("   📌 Will load best model (lowest eval_loss) at end")
print(f"   📌 Early stopping: patience={EARLY_STOPPING_PATIENCE}")
# Out:
# ✅ Training arguments configured for Scene task
#    📌 Will load best model (lowest eval_loss) at end
#    📌 Early stopping: patience=5

# %%
# Custom trainer for scene task
from transformers import EarlyStoppingCallback

class SceneTrainer(IQATrainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        outputs = model.forward_scene_task(
            pixel_values_A=inputs["pixel_values_A"],
            input_ids_scene_A=inputs["input_ids_scene_A"],
            attention_mask_scene_A=inputs["attention_mask_scene_A"],
            labels_scene_A=inputs["labels_scene_A"],
            media_offset_A=inputs["media_offset_A"],
            pixel_values_B=inputs["pixel_values_B"],
            input_ids_scene_B=inputs["input_ids_scene_B"],
            attention_mask_scene_B=inputs["attention_mask_scene_B"],
            labels_scene_B=inputs["labels_scene_B"],
            media_offset_B=inputs["media_offset_B"],
        )
        loss = outputs["loss"]
        return (loss, outputs) if return_outputs else loss
    
    def prediction_step(self, model, inputs, prediction_loss_only: bool, ignore_keys=None):
        has_labels = "labels_scene_A" in inputs and "labels_scene_B" in inputs
        with torch.no_grad():
            if has_labels:
                loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
                loss = loss.mean().detach()
            else:
                loss = None
        return (loss, None, None)

# Create early stopping callback
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=EARLY_STOPPING_PATIENCE,
    early_stopping_threshold=0.0,  # Any improvement counts
)

# Create trainer
trainer_scene = SceneTrainer(
    model=model,
    args=training_args_scene,
    train_dataset=train_dataset_scene,
    eval_dataset=val_dataset_scene,
    data_collator=collate_fn_scene,
    callbacks=[early_stopping_callback],
)

print("✅ Scene trainer created!")
print(f"   🛑 Early stopping enabled: patience={EARLY_STOPPING_PATIENCE}")
# Out:
# ✅ Scene trainer created!
#    🛑 Early stopping enabled: patience=5

# %%
# Train Scene task
print("\n🚀 Starting Scene classification training...")
print("="*80)
trainer_scene.train()
print("="*80)
print("\n✅ Scene training completed!")

# Generate plots
print("\n📊 Generating training curves...")
plot_training_curves(output_dir=output_dir_scene)
print(f"✅ Plots saved to {output_dir_scene}/")
# Out:
# 🚀 Starting Scene classification training...
# ================================================================================
# The attention layers in this model are transitioning from computing the RoPE embeddings internally through `position_ids` (2D tensor with the indexes of the tokens), to using externally computed `position_embeddings` (Tuple of tensors, containing cos and sin). In v4.46 `position_ids` will be removed and `position_embeddings` will be mandatory.
#     <div>
#
#       <progress value='800' max='2718' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 800/2718 46:36 < 1:52:02, 0.29 it/s, Epoch 0/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.053800</td>
#       <td>0.041473</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.035700</td>
#       <td>0.035143</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.042500</td>
#       <td>0.032507</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.032900</td>
#       <td>0.032796</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.023700</td>
#       <td>0.045602</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.045000</td>
#       <td>0.035222</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.063000</td>
#       <td>0.037553</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.031900</td>
#       <td>0.038823</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 0.06 | Loss: 0.3504
# Epoch 0.11 | Loss: 0.0538
# Epoch 0.11 | Loss: 0.0538
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       0.041473
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       0.041473
# ======================================================================
#
# Epoch 0.17 | Loss: 0.0402
# Epoch 0.17 | Loss: 0.0402
# Epoch 0.22 | Loss: 0.0357
# Epoch 0.22 | Loss: 0.0357
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       0.035143
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       0.035143
# ======================================================================
#
# Epoch 0.28 | Loss: 0.0391
# Epoch 0.28 | Loss: 0.0391
# Epoch 0.33 | Loss: 0.0425
# Epoch 0.33 | Loss: 0.0425
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       0.032507
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       0.032507
# ======================================================================
#
# Epoch 0.39 | Loss: 0.0324
# Epoch 0.39 | Loss: 0.0324
# Epoch 0.44 | Loss: 0.0329
# Epoch 0.44 | Loss: 0.0329
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       0.032796
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       0.032796
# ======================================================================
#
# Epoch 0.50 | Loss: 0.0216
# Epoch 0.50 | Loss: 0.0216
# Epoch 0.55 | Loss: 0.0237
# Epoch 0.55 | Loss: 0.0237
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       0.045602
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       0.045602
# ======================================================================
#
# Epoch 0.61 | Loss: 0.0394
# Epoch 0.61 | Loss: 0.0394
# Epoch 0.66 | Loss: 0.0450
# Epoch 0.66 | Loss: 0.0450
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       0.035222
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       0.035222
# ======================================================================
#
# Epoch 0.72 | Loss: 0.0329
# Epoch 0.72 | Loss: 0.0329
# Epoch 0.77 | Loss: 0.0630
# Epoch 0.77 | Loss: 0.0630
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       0.037553
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       0.037553
# ======================================================================
#
# Epoch 0.83 | Loss: 0.0216
# Epoch 0.83 | Loss: 0.0216
# Epoch 0.88 | Loss: 0.0319
# Epoch 0.88 | Loss: 0.0319
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       0.038823
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       0.038823
# ======================================================================
#
# ================================================================================
#
# ✅ Scene training completed!
#
# 📊 Generating training curves...
#
# 📊 Training curves saved to: outputs/10270900/01_scene/training_curves.png
# ================================================================================
#
# ✅ Scene training completed!
#
# 📊 Generating training curves...
#
# 📊 Training curves saved to: outputs/10270900/01_scene/training_curves.png
# 📊 Training curves (PDF) saved to: outputs/10270900/01_scene/training_curves.pdf
# ✅ Plots saved to outputs/10270900/01_scene/
# 📊 Training curves (PDF) saved to: outputs/10270900/01_scene/training_curves.pdf
# ✅ Plots saved to outputs/10270900/01_scene/

# %% [markdown]
# ---
# ## Stage 2: Distortion Classification Training
#
# Build on Scene knowledge to classify distortion types (e.g., blur, noise, compression, etc.)

# %%
print("="*80)
print("STAGE 2/3: Distortion Classification Training")
print("="*80)
print("Building on Scene classification knowledge...")

# Create dataset
print("\n📊 Creating distortion classification dataset...")
train_dataset_distortion = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="training",
    use_scene_labels=False,
    use_distortion_labels=True,
)

val_dataset_distortion = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="validation",
    use_scene_labels=False,
    use_distortion_labels=True,
)

print(f"✅ Training dataset size: {len(train_dataset_distortion)}")
print(f"✅ Validation dataset size: {len(val_dataset_distortion)}")
# Out:
# ================================================================================
# STAGE 2/3: Distortion Classification Training
# ================================================================================
# Building on Scene classification knowledge...
#
# 📊 Creating distortion classification dataset...
# ✅ Training dataset size: 7252
# ✅ Validation dataset size: 1813

# %%
# Training arguments for Distortion task
output_dir_distortion = f"{OUTPUT_DIR}/02_distortion"
training_args_distortion = TrainingArguments(
    output_dir=output_dir_distortion,
    num_train_epochs=NUM_TRAIN_EPOCHS if MAX_STEPS <= 0 else 1,
    max_steps=MAX_STEPS if MAX_STEPS > 0 else -1,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRAD_ACCUM,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type="cosine",
    warmup_ratio=0.03,
    weight_decay=0.0,
    logging_steps=LOGGING_STEPS,
    eval_strategy="steps",
    eval_steps=EVAL_STEPS,
    save_strategy="steps",
    save_steps=SAVE_STEPS,
    save_total_limit=2,
    bf16=True,
    dataloader_num_workers=12,
    remove_unused_columns=False,
    report_to="none",
    load_best_model_at_end=True,  # Load best model based on eval_loss
    metric_for_best_model="eval_loss",
    greater_is_better=False,  # Lower loss is better
)

print("✅ Training arguments configured for Distortion task")
print("   📌 Will load best model (lowest eval_loss) at end")
print(f"   📌 Early stopping: patience={EARLY_STOPPING_PATIENCE}")
# Out:
# ✅ Training arguments configured for Distortion task
#    📌 Will load best model (lowest eval_loss) at end
#    📌 Early stopping: patience=5

# %%
# Custom trainer for distortion task
class DistortionTrainer(IQATrainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        outputs = model.forward_distortion_task(
            pixel_values_A=inputs["pixel_values_A"],
            input_ids_distortion_A=inputs["input_ids_distortion_A"],
            attention_mask_distortion_A=inputs["attention_mask_distortion_A"],
            labels_distortion_A=inputs["labels_distortion_A"],
            media_offset_A=inputs["media_offset_A"],
            pixel_values_B=inputs["pixel_values_B"],
            input_ids_distortion_B=inputs["input_ids_distortion_B"],
            attention_mask_distortion_B=inputs["attention_mask_distortion_B"],
            labels_distortion_B=inputs["labels_distortion_B"],
            media_offset_B=inputs["media_offset_B"],
        )
        loss = outputs["loss"]
        return (loss, outputs) if return_outputs else loss
    
    def prediction_step(self, model, inputs, prediction_loss_only: bool, ignore_keys=None):
        has_labels = "labels_distortion_A" in inputs and "labels_distortion_B" in inputs
        with torch.no_grad():
            if has_labels:
                loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
                loss = loss.mean().detach()
            else:
                loss = None
        return (loss, None, None)

print("✅ DistortionTrainer class defined!")
# Out:
# ✅ DistortionTrainer class defined!

# %%
# Create distortion trainer
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=EARLY_STOPPING_PATIENCE,
    early_stopping_threshold=0.0,
)

trainer_distortion = DistortionTrainer(
    model=model,
    args=training_args_distortion,
    train_dataset=train_dataset_distortion,
    eval_dataset=val_dataset_distortion,
    data_collator=collate_fn_distortion,
    callbacks=[early_stopping_callback],
)

print("✅ Distortion trainer created with early stopping!")
# Out:
# ✅ Distortion trainer created with early stopping!

# %%
# Train Distortion task
print("\n🚀 Starting Distortion classification training...")
print("="*80)
trainer_distortion.train()
print("="*80)
print("\n✅ Distortion training completed!")

# Generate plots
print("\n📊 Generating training curves...")
plot_training_curves(output_dir=output_dir_distortion)
print(f"✅ Plots saved to {output_dir_distortion}/")
# Out:
# 🚀 Starting Distortion classification training...
# ================================================================================
#     <div>
#
#       <progress value='1300' max='2718' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1300/2718 1:18:58 < 1:26:16, 0.27 it/s, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.065400</td>
#       <td>0.053710</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.043300</td>
#       <td>0.059190</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.044100</td>
#       <td>0.050715</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.045500</td>
#       <td>0.045591</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.040100</td>
#       <td>0.047934</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.040600</td>
#       <td>0.049053</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.033900</td>
#       <td>0.050499</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.036900</td>
#       <td>0.044182</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.036000</td>
#       <td>0.051400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.026400</td>
#       <td>0.064265</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.026200</td>
#       <td>0.053172</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.022300</td>
#       <td>0.050895</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.023000</td>
#       <td>0.056698</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 0.06 | Loss: 0.1391
# Epoch 0.11 | Loss: 0.0654
# Epoch 0.11 | Loss: 0.0654
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       0.053710
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       0.053710
# ======================================================================
#
# Epoch 0.17 | Loss: 0.0456
# Epoch 0.17 | Loss: 0.0456
# Epoch 0.22 | Loss: 0.0433
# Epoch 0.22 | Loss: 0.0433
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       0.059190
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       0.059190
# ======================================================================
#
# Epoch 0.28 | Loss: 0.0445
# Epoch 0.28 | Loss: 0.0445
# Epoch 0.33 | Loss: 0.0441
# Epoch 0.33 | Loss: 0.0441
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       0.050715
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       0.050715
# ======================================================================
#
# Epoch 0.39 | Loss: 0.0504
# Epoch 0.39 | Loss: 0.0504
# Epoch 0.44 | Loss: 0.0455
# Epoch 0.44 | Loss: 0.0455
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       0.045591
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       0.045591
# ======================================================================
#
# Epoch 0.50 | Loss: 0.0379
# Epoch 0.50 | Loss: 0.0379
# Epoch 0.55 | Loss: 0.0401
# Epoch 0.55 | Loss: 0.0401
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       0.047934
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       0.047934
# ======================================================================
#
# Epoch 0.61 | Loss: 0.0416
# Epoch 0.61 | Loss: 0.0416
# Epoch 0.66 | Loss: 0.0406
# Epoch 0.66 | Loss: 0.0406
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       0.049053
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       0.049053
# ======================================================================
#
# Epoch 0.72 | Loss: 0.0346
# Epoch 0.72 | Loss: 0.0346
# Epoch 0.77 | Loss: 0.0339
# Epoch 0.77 | Loss: 0.0339
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       0.050499
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       0.050499
# ======================================================================
#
# Epoch 0.83 | Loss: 0.0334
# Epoch 0.83 | Loss: 0.0334
# Epoch 0.88 | Loss: 0.0369
# Epoch 0.88 | Loss: 0.0369
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       0.044182
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       0.044182
# ======================================================================
#
# Epoch 0.94 | Loss: 0.0316
# Epoch 0.94 | Loss: 0.0316
# Epoch 0.99 | Loss: 0.0360
# Epoch 0.99 | Loss: 0.0360
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.99
# ======================================================================
#   Loss:       0.051400
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 0.99
# ======================================================================
#   Loss:       0.051400
# ======================================================================
#
# Epoch 1.05 | Loss: 0.0274
# Epoch 1.05 | Loss: 0.0274
# Epoch 1.10 | Loss: 0.0264
# Epoch 1.10 | Loss: 0.0264
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.10
# ======================================================================
#   Loss:       0.064265
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.10
# ======================================================================
#   Loss:       0.064265
# ======================================================================
#
# Epoch 1.16 | Loss: 0.0247
# Epoch 1.16 | Loss: 0.0247
# Epoch 1.21 | Loss: 0.0262
# Epoch 1.21 | Loss: 0.0262
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.21
# ======================================================================
#   Loss:       0.053172
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.21
# ======================================================================
#   Loss:       0.053172
# ======================================================================
#
# Epoch 1.27 | Loss: 0.0242
# Epoch 1.27 | Loss: 0.0242
# Epoch 1.32 | Loss: 0.0223
# Epoch 1.32 | Loss: 0.0223
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.32
# ======================================================================
#   Loss:       0.050895
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.32
# ======================================================================
#   Loss:       0.050895
# ======================================================================
#
# Epoch 1.38 | Loss: 0.0228
# Epoch 1.38 | Loss: 0.0228
# Epoch 1.43 | Loss: 0.0230
# Epoch 1.43 | Loss: 0.0230
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.43
# ======================================================================
#   Loss:       0.056698
# ======================================================================
#
#
# [DEBUG] Collected 0 predictions
#
# ======================================================================
# 📊 Validation Results at Epoch 1.43
# ======================================================================
#   Loss:       0.056698
# ======================================================================
#
# ================================================================================
#
# ✅ Distortion training completed!
#
# 📊 Generating training curves...
#
# 📊 Training curves saved to: outputs/10270900/02_distortion/training_curves.png
# 📊 Training curves (PDF) saved to: outputs/10270900/02_distortion/training_curves.pdf
# ✅ Plots saved to outputs/10270900/02_distortion/
# ================================================================================
#
# ✅ Distortion training completed!
#
# 📊 Generating training curves...
#
# 📊 Training curves saved to: outputs/10270900/02_distortion/training_curves.png
# 📊 Training curves (PDF) saved to: outputs/10270900/02_distortion/training_curves.pdf
# ✅ Plots saved to outputs/10270900/02_distortion/

# %% [markdown]
# ---
# ## Stage 3: Quality Assessment Training
#
# Build on Scene + Distortion knowledge to predict image quality scores

# %%
print("="*80)
print("STAGE 3/3: Quality Assessment Training")
print("="*80)
print("Building on Scene + Distortion classification knowledge...")

# Create dataset
print("\n📊 Creating quality assessment dataset...")
train_dataset_quality = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="training",
    use_scene_labels=False,
    use_distortion_labels=False,
)

val_dataset_quality = IQAPairDataset(
    dataset_paths=dataset_paths,
    processor=processor,
    tokenizer=tokenizer,
    split="validation",
    use_scene_labels=False,
    use_distortion_labels=False,
)

print(f"✅ Training dataset size: {len(train_dataset_quality)}")
print(f"✅ Validation dataset size: {len(val_dataset_quality)}")
# Out:
# ================================================================================
# STAGE 3/3: Quality Assessment Training
# ================================================================================
# Building on Scene + Distortion classification knowledge...
#
# 📊 Creating quality assessment dataset...
# ✅ Training dataset size: 7252
# ✅ Validation dataset size: 1813

# %%
# Training arguments for Quality task
output_dir_quality = f"{OUTPUT_DIR}/03_quality"
training_args_quality = TrainingArguments(
    output_dir=output_dir_quality,
    num_train_epochs=NUM_TRAIN_EPOCHS if MAX_STEPS <= 0 else 1,
    max_steps=MAX_STEPS if MAX_STEPS > 0 else -1,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    gradient_accumulation_steps=GRAD_ACCUM,
    learning_rate=LEARNING_RATE,
    lr_scheduler_type="cosine",
    warmup_ratio=0.03,
    weight_decay=0.0,
    logging_steps=LOGGING_STEPS,
    eval_strategy="steps",
    eval_steps=EVAL_STEPS,
    save_strategy="steps",
    save_steps=SAVE_STEPS,
    save_total_limit=2,
    bf16=True,
    dataloader_num_workers=12,
    remove_unused_columns=False,
    report_to="none",
    load_best_model_at_end=True,  # Load best model based on eval_plcc
    metric_for_best_model="eval_plcc",
    greater_is_better=True,  # Higher PLCC is better
)

print("✅ Training arguments configured for Quality task")
print("   📌 Will load best model (highest eval_plcc) at end")
# Out:
# ✅ Training arguments configured for Quality task
#    📌 Will load best model (highest eval_plcc) at end

# %%
# Create trainer for quality task (uses standard IQATrainer)
early_stopping_callback = EarlyStoppingCallback(
    early_stopping_patience=EARLY_STOPPING_PATIENCE,
    early_stopping_threshold=0.0,
)

trainer_quality = IQATrainer(
    model=model,
    args=training_args_quality,
    train_dataset=train_dataset_quality,
    eval_dataset=val_dataset_quality,
    data_collator=collate_fn_pair,
    tokenizer=tokenizer,
    callbacks=[early_stopping_callback],
)

print("✅ Quality trainer created with early stopping!")
# Out:
# ✅ Quality trainer created with early stopping!
# /home/wytsai7660/code/iqa-project/src/new_train/iqa_trainer.py:68: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `IQATrainer.__init__`. Use `processing_class` instead.
#   super().__init__(*args, **kwargs)

# %%
# Train Quality task
print("\n🚀 Starting Quality assessment training...")
print("="*80)
trainer_quality.train()
print("="*80)
print("\n✅ Quality training completed!")

# Generate plots
print("\n📊 Generating training curves...")
try:
    from src.new_train.plot_utils import plot_metrics_summary, plot_correlation_metrics
    plot_training_curves(output_dir_quality)
    plot_metrics_summary(output_dir_quality)
    plot_correlation_metrics(output_dir_quality)
    print("✅ All plots saved!")
except Exception as e:
    print(f"⚠️  Could not generate all plots: {e}")
    plot_training_curves(output_dir_quality)

print(f"✅ Plots saved to {output_dir_quality}/")
# Out:
# 🚀 Starting Quality assessment training...
# ================================================================================
#     <div>
#
#       <progress value='2718' max='2718' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2718/2718 2:57:59, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mae</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Plcc</th>
#       <th>Srcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>12450.152500</td>
#       <td>nan</td>
#       <td>0.358433</td>
#       <td>0.170510</td>
#       <td>0.412929</td>
#       <td>0.941295</td>
#       <td>0.930138</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>953148.720000</td>
#       <td>nan</td>
#       <td>0.192019</td>
#       <td>0.060161</td>
#       <td>0.245277</td>
#       <td>0.944881</td>
#       <td>0.933592</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1118878.080000</td>
#       <td>nan</td>
#       <td>0.298067</td>
#       <td>0.127900</td>
#       <td>0.357631</td>
#       <td>0.934818</td>
#       <td>0.928414</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>242715340.800000</td>
#       <td>nan</td>
#       <td>0.206402</td>
#       <td>0.066827</td>
#       <td>0.258510</td>
#       <td>0.947093</td>
#       <td>0.940462</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>115057295.360000</td>
#       <td>nan</td>
#       <td>0.202155</td>
#       <td>0.065722</td>
#       <td>0.256364</td>
#       <td>0.949322</td>
#       <td>0.938725</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>4889177.600000</td>
#       <td>nan</td>
#       <td>0.256306</td>
#       <td>0.094954</td>
#       <td>0.308146</td>
#       <td>0.945342</td>
#       <td>0.940845</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>9975.336900</td>
#       <td>nan</td>
#       <td>0.243136</td>
#       <td>0.088088</td>
#       <td>0.296796</td>
#       <td>0.952253</td>
#       <td>0.945019</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>143704.730000</td>
#       <td>nan</td>
#       <td>0.173627</td>
#       <td>0.049772</td>
#       <td>0.223096</td>
#       <td>0.954000</td>
#       <td>0.944444</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1614763.680000</td>
#       <td>nan</td>
#       <td>0.169912</td>
#       <td>0.048753</td>
#       <td>0.220801</td>
#       <td>0.954288</td>
#       <td>0.945611</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>4607913.920000</td>
#       <td>nan</td>
#       <td>0.205648</td>
#       <td>0.063888</td>
#       <td>0.252761</td>
#       <td>0.954663</td>
#       <td>0.947916</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>3318302.080000</td>
#       <td>nan</td>
#       <td>0.253780</td>
#       <td>0.091984</td>
#       <td>0.303289</td>
#       <td>0.947420</td>
#       <td>0.946623</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>907361.920000</td>
#       <td>nan</td>
#       <td>0.200899</td>
#       <td>0.062095</td>
#       <td>0.249190</td>
#       <td>0.956920</td>
#       <td>0.948596</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>2207395.840000</td>
#       <td>nan</td>
#       <td>0.249096</td>
#       <td>0.088042</td>
#       <td>0.296719</td>
#       <td>0.958315</td>
#       <td>0.948962</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>95384248.320000</td>
#       <td>nan</td>
#       <td>0.188572</td>
#       <td>0.057009</td>
#       <td>0.238765</td>
#       <td>0.959372</td>
#       <td>0.949454</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>168448829.440000</td>
#       <td>nan</td>
#       <td>0.200834</td>
#       <td>0.062765</td>
#       <td>0.250529</td>
#       <td>0.955672</td>
#       <td>0.947283</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1553360.800000</td>
#       <td>nan</td>
#       <td>0.216654</td>
#       <td>0.070004</td>
#       <td>0.264582</td>
#       <td>0.958290</td>
#       <td>0.951107</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>59613260.800000</td>
#       <td>nan</td>
#       <td>0.175440</td>
#       <td>0.049642</td>
#       <td>0.222804</td>
#       <td>0.958243</td>
#       <td>0.951525</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>46143201.280000</td>
#       <td>nan</td>
#       <td>0.185430</td>
#       <td>0.053170</td>
#       <td>0.230587</td>
#       <td>0.959630</td>
#       <td>0.950490</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>6560.366300</td>
#       <td>nan</td>
#       <td>0.191992</td>
#       <td>0.057624</td>
#       <td>0.240049</td>
#       <td>0.960974</td>
#       <td>0.951854</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>401007.000000</td>
#       <td>nan</td>
#       <td>0.168925</td>
#       <td>0.046420</td>
#       <td>0.215454</td>
#       <td>0.959308</td>
#       <td>0.950631</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>5939954.560000</td>
#       <td>nan</td>
#       <td>0.191833</td>
#       <td>0.057608</td>
#       <td>0.240017</td>
#       <td>0.956526</td>
#       <td>0.951672</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>39372.620000</td>
#       <td>nan</td>
#       <td>0.186823</td>
#       <td>0.054545</td>
#       <td>0.233548</td>
#       <td>0.959199</td>
#       <td>0.951778</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>135894210.560000</td>
#       <td>nan</td>
#       <td>0.187893</td>
#       <td>0.054622</td>
#       <td>0.233714</td>
#       <td>0.960726</td>
#       <td>0.951283</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>270.927400</td>
#       <td>nan</td>
#       <td>0.189867</td>
#       <td>0.055396</td>
#       <td>0.235363</td>
#       <td>0.961221</td>
#       <td>0.951717</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2260695.840000</td>
#       <td>nan</td>
#       <td>0.185336</td>
#       <td>0.053094</td>
#       <td>0.230420</td>
#       <td>0.960132</td>
#       <td>0.951772</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>3246790.400000</td>
#       <td>nan</td>
#       <td>0.188229</td>
#       <td>0.054850</td>
#       <td>0.234201</td>
#       <td>0.960526</td>
#       <td>0.952118</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>57590.170000</td>
#       <td>nan</td>
#       <td>0.186258</td>
#       <td>0.053706</td>
#       <td>0.231746</td>
#       <td>0.960774</td>
#       <td>0.951809</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 0.06 | Loss: 8625001594.8800
# Epoch 0.11 | Loss: 12450.1525
# Epoch 0.11 | Loss: 12450.1525
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.3584327139515148, 'mse': 0.170510122627504, 'rmse': 0.4129287137358021, 'plcc': 0.9412946800950742, 'srcc': 0.9301384944331513}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       nan
#   MAE:        0.3584
#   RMSE:       0.4129
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9413  [██████████████████░░]
#   SRCC:       0.9301  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.3584327139515148, 'mse': 0.170510122627504, 'rmse': 0.4129287137358021, 'plcc': 0.9412946800950742, 'srcc': 0.9301384944331513}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.11
# ======================================================================
#   Loss:       nan
#   MAE:        0.3584
#   RMSE:       0.4129
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9413  [██████████████████░░]
#   SRCC:       0.9301  [██████████████████░░]
# ======================================================================
#
# Epoch 0.17 | Loss: 124528.4700
# Epoch 0.17 | Loss: 124528.4700
# Epoch 0.22 | Loss: 953148.7200
# Epoch 0.22 | Loss: 953148.7200
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1920190836537693, 'mse': 0.060160942891879135, 'rmse': 0.24527727756944614, 'plcc': 0.9448806083693387, 'srcc': 0.9335923177399088}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       nan
#   MAE:        0.1920
#   RMSE:       0.2453
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9449  [██████████████████░░]
#   SRCC:       0.9336  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1920190836537693, 'mse': 0.060160942891879135, 'rmse': 0.24527727756944614, 'plcc': 0.9448806083693387, 'srcc': 0.9335923177399088}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.22
# ======================================================================
#   Loss:       nan
#   MAE:        0.1920
#   RMSE:       0.2453
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9449  [██████████████████░░]
#   SRCC:       0.9336  [██████████████████░░]
# ======================================================================
#
# Epoch 0.28 | Loss: 102508032.0000
# Epoch 0.28 | Loss: 102508032.0000
# Epoch 0.33 | Loss: 1118878.0800
# Epoch 0.33 | Loss: 1118878.0800
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.29806738444211006, 'mse': 0.12790010478354155, 'rmse': 0.3576312413416109, 'plcc': 0.9348182857978616, 'srcc': 0.92841375171935}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       nan
#   MAE:        0.2981
#   RMSE:       0.3576
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9348  [██████████████████░░]
#   SRCC:       0.9284  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.29806738444211006, 'mse': 0.12790010478354155, 'rmse': 0.3576312413416109, 'plcc': 0.9348182857978616, 'srcc': 0.92841375171935}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.33
# ======================================================================
#   Loss:       nan
#   MAE:        0.2981
#   RMSE:       0.3576
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9348  [██████████████████░░]
#   SRCC:       0.9284  [██████████████████░░]
# ======================================================================
#
# Epoch 0.39 | Loss: 35084.8850
# Epoch 0.39 | Loss: 35084.8850
# Epoch 0.44 | Loss: 242715340.8000
# Epoch 0.44 | Loss: 242715340.8000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20640215397670134, 'mse': 0.06682721547843704, 'rmse': 0.25850960422861863, 'plcc': 0.9470932839264314, 'srcc': 0.9404617573377596}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       nan
#   MAE:        0.2064
#   RMSE:       0.2585
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9471  [██████████████████░░]
#   SRCC:       0.9405  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20640215397670134, 'mse': 0.06682721547843704, 'rmse': 0.25850960422861863, 'plcc': 0.9470932839264314, 'srcc': 0.9404617573377596}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.44
# ======================================================================
#   Loss:       nan
#   MAE:        0.2064
#   RMSE:       0.2585
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9471  [██████████████████░░]
#   SRCC:       0.9405  [██████████████████░░]
# ======================================================================
#
# Epoch 0.50 | Loss: 184911462.4000
# Epoch 0.50 | Loss: 184911462.4000
# Epoch 0.55 | Loss: 115057295.3600
# Epoch 0.55 | Loss: 115057295.3600
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20215486691133527, 'mse': 0.06572241366343902, 'rmse': 0.2563638306458987, 'plcc': 0.9493219472227031, 'srcc': 0.9387246879718334}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       nan
#   MAE:        0.2022
#   RMSE:       0.2564
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9493  [██████████████████░░]
#   SRCC:       0.9387  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20215486691133527, 'mse': 0.06572241366343902, 'rmse': 0.2563638306458987, 'plcc': 0.9493219472227031, 'srcc': 0.9387246879718334}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.55
# ======================================================================
#   Loss:       nan
#   MAE:        0.2022
#   RMSE:       0.2564
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9493  [██████████████████░░]
#   SRCC:       0.9387  [██████████████████░░]
# ======================================================================
#
# Epoch 0.61 | Loss: 21709360.6400
# Epoch 0.61 | Loss: 21709360.6400
# Epoch 0.66 | Loss: 4889177.6000
# Epoch 0.66 | Loss: 4889177.6000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.2563061662227885, 'mse': 0.09495393322206794, 'rmse': 0.3081459609050035, 'plcc': 0.945341850427793, 'srcc': 0.9408452377841126}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       nan
#   MAE:        0.2563
#   RMSE:       0.3081
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9453  [██████████████████░░]
#   SRCC:       0.9408  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.2563061662227885, 'mse': 0.09495393322206794, 'rmse': 0.3081459609050035, 'plcc': 0.945341850427793, 'srcc': 0.9408452377841126}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.66
# ======================================================================
#   Loss:       nan
#   MAE:        0.2563
#   RMSE:       0.3081
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9453  [██████████████████░░]
#   SRCC:       0.9408  [██████████████████░░]
# ======================================================================
#
# Epoch 0.72 | Loss: 1019907.1200
# Epoch 0.72 | Loss: 1019907.1200
# Epoch 0.77 | Loss: 9975.3369
# Epoch 0.77 | Loss: 9975.3369
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.24313565939089507, 'mse': 0.08808807377473564, 'rmse': 0.2967963506762434, 'plcc': 0.9522534735406727, 'srcc': 0.9450186426654993}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       nan
#   MAE:        0.2431
#   RMSE:       0.2968
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9523  [███████████████████░]
#   SRCC:       0.9450  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.24313565939089507, 'mse': 0.08808807377473564, 'rmse': 0.2967963506762434, 'plcc': 0.9522534735406727, 'srcc': 0.9450186426654993}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.77
# ======================================================================
#   Loss:       nan
#   MAE:        0.2431
#   RMSE:       0.2968
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9523  [███████████████████░]
#   SRCC:       0.9450  [██████████████████░░]
# ======================================================================
#
# Epoch 0.83 | Loss: 1006725.8400
# Epoch 0.83 | Loss: 1006725.8400
# Epoch 0.88 | Loss: 143704.7300
# Epoch 0.88 | Loss: 143704.7300
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1736267902413193, 'mse': 0.0497716759555936, 'rmse': 0.22309566547916973, 'plcc': 0.9540004481859928, 'srcc': 0.9444436774042354}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       nan
#   MAE:        0.1736
#   RMSE:       0.2231
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9540  [███████████████████░]
#   SRCC:       0.9444  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1736267902413193, 'mse': 0.0497716759555936, 'rmse': 0.22309566547916973, 'plcc': 0.9540004481859928, 'srcc': 0.9444436774042354}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.88
# ======================================================================
#   Loss:       nan
#   MAE:        0.1736
#   RMSE:       0.2231
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9540  [███████████████████░]
#   SRCC:       0.9444  [██████████████████░░]
# ======================================================================
#
# Epoch 0.94 | Loss: 209291898.8800
# Epoch 0.94 | Loss: 209291898.8800
# Epoch 0.99 | Loss: 1614763.6800
# Epoch 0.99 | Loss: 1614763.6800
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.16991212410093076, 'mse': 0.04875317943842013, 'rmse': 0.22080122155101436, 'plcc': 0.9542876336346577, 'srcc': 0.9456111249774303}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.99
# ======================================================================
#   Loss:       nan
#   MAE:        0.1699
#   RMSE:       0.2208
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9543  [███████████████████░]
#   SRCC:       0.9456  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.16991212410093076, 'mse': 0.04875317943842013, 'rmse': 0.22080122155101436, 'plcc': 0.9542876336346577, 'srcc': 0.9456111249774303}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 0.99
# ======================================================================
#   Loss:       nan
#   MAE:        0.1699
#   RMSE:       0.2208
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9543  [███████████████████░]
#   SRCC:       0.9456  [██████████████████░░]
# ======================================================================
#
# Epoch 1.05 | Loss: 410808.4800
# Epoch 1.05 | Loss: 410808.4800
# Epoch 1.10 | Loss: 4607913.9200
# Epoch 1.10 | Loss: 4607913.9200
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20564814693547714, 'mse': 0.06388829091203592, 'rmse': 0.25276133191616934, 'plcc': 0.9546633804936809, 'srcc': 0.9479160492143028}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.10
# ======================================================================
#   Loss:       nan
#   MAE:        0.2056
#   RMSE:       0.2528
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9547  [███████████████████░]
#   SRCC:       0.9479  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20564814693547714, 'mse': 0.06388829091203592, 'rmse': 0.25276133191616934, 'plcc': 0.9546633804936809, 'srcc': 0.9479160492143028}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.10
# ======================================================================
#   Loss:       nan
#   MAE:        0.2056
#   RMSE:       0.2528
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9547  [███████████████████░]
#   SRCC:       0.9479  [██████████████████░░]
# ======================================================================
#
# Epoch 1.16 | Loss: 436802.0400
# Epoch 1.16 | Loss: 436802.0400
# Epoch 1.21 | Loss: 3318302.0800
# Epoch 1.21 | Loss: 3318302.0800
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.25378022276756845, 'mse': 0.09198420056810701, 'rmse': 0.30328897205158484, 'plcc': 0.9474204057564686, 'srcc': 0.946622991674204}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.21
# ======================================================================
#   Loss:       nan
#   MAE:        0.2538
#   RMSE:       0.3033
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9474  [██████████████████░░]
#   SRCC:       0.9466  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.25378022276756845, 'mse': 0.09198420056810701, 'rmse': 0.30328897205158484, 'plcc': 0.9474204057564686, 'srcc': 0.946622991674204}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.21
# ======================================================================
#   Loss:       nan
#   MAE:        0.2538
#   RMSE:       0.3033
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9474  [██████████████████░░]
#   SRCC:       0.9466  [██████████████████░░]
# ======================================================================
#
# Epoch 1.27 | Loss: 18791.2762
# Epoch 1.27 | Loss: 18791.2762
# Epoch 1.32 | Loss: 907361.9200
# Epoch 1.32 | Loss: 907361.9200
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20089938538020577, 'mse': 0.06209547994944951, 'rmse': 0.24918964655348244, 'plcc': 0.9569202174219414, 'srcc': 0.9485960752125647}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.32
# ======================================================================
#   Loss:       nan
#   MAE:        0.2009
#   RMSE:       0.2492
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9569  [███████████████████░]
#   SRCC:       0.9486  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20089938538020577, 'mse': 0.06209547994944951, 'rmse': 0.24918964655348244, 'plcc': 0.9569202174219414, 'srcc': 0.9485960752125647}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.32
# ======================================================================
#   Loss:       nan
#   MAE:        0.2009
#   RMSE:       0.2492
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9569  [███████████████████░]
#   SRCC:       0.9486  [██████████████████░░]
# ======================================================================
#
# Epoch 1.38 | Loss: 97579.5800
# Epoch 1.38 | Loss: 97579.5800
# Epoch 1.43 | Loss: 2207395.8400
# Epoch 1.43 | Loss: 2207395.8400
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.24909575026270703, 'mse': 0.08804218989167795, 'rmse': 0.2967190420105827, 'plcc': 0.9583152501827289, 'srcc': 0.9489616771074577}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.43
# ======================================================================
#   Loss:       nan
#   MAE:        0.2491
#   RMSE:       0.2967
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9583  [███████████████████░]
#   SRCC:       0.9490  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.24909575026270703, 'mse': 0.08804218989167795, 'rmse': 0.2967190420105827, 'plcc': 0.9583152501827289, 'srcc': 0.9489616771074577}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.43
# ======================================================================
#   Loss:       nan
#   MAE:        0.2491
#   RMSE:       0.2967
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9583  [███████████████████░]
#   SRCC:       0.9490  [██████████████████░░]
# ======================================================================
#
# Epoch 1.49 | Loss: 139316.3900
# Epoch 1.49 | Loss: 139316.3900
# Epoch 1.54 | Loss: 95384248.3200
# Epoch 1.54 | Loss: 95384248.3200
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.188571623327715, 'mse': 0.05700868978406965, 'rmse': 0.23876492578280767, 'plcc': 0.9593720205390955, 'srcc': 0.9494543066001037}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.54
# ======================================================================
#   Loss:       nan
#   MAE:        0.1886
#   RMSE:       0.2388
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9594  [███████████████████░]
#   SRCC:       0.9495  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.188571623327715, 'mse': 0.05700868978406965, 'rmse': 0.23876492578280767, 'plcc': 0.9593720205390955, 'srcc': 0.9494543066001037}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.54
# ======================================================================
#   Loss:       nan
#   MAE:        0.1886
#   RMSE:       0.2388
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9594  [███████████████████░]
#   SRCC:       0.9495  [██████████████████░░]
# ======================================================================
#
# Epoch 1.60 | Loss: 206800773.1200
# Epoch 1.60 | Loss: 206800773.1200
# Epoch 1.65 | Loss: 168448829.4400
# Epoch 1.65 | Loss: 168448829.4400
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20083416428805317, 'mse': 0.06276497376864947, 'rmse': 0.2505293870360311, 'plcc': 0.9556720464984445, 'srcc': 0.9472828742219019}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.65
# ======================================================================
#   Loss:       nan
#   MAE:        0.2008
#   RMSE:       0.2505
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9557  [███████████████████░]
#   SRCC:       0.9473  [██████████████████░░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.20083416428805317, 'mse': 0.06276497376864947, 'rmse': 0.2505293870360311, 'plcc': 0.9556720464984445, 'srcc': 0.9472828742219019}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.65
# ======================================================================
#   Loss:       nan
#   MAE:        0.2008
#   RMSE:       0.2505
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9557  [███████████████████░]
#   SRCC:       0.9473  [██████████████████░░]
# ======================================================================
#
# Epoch 1.71 | Loss: 81701.3150
# Epoch 1.71 | Loss: 81701.3150
# Epoch 1.76 | Loss: 1553360.8000
# Epoch 1.76 | Loss: 1553360.8000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.21665397100664277, 'mse': 0.07000376852677301, 'rmse': 0.26458225285678744, 'plcc': 0.9582898944410304, 'srcc': 0.9511071327643235}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.76
# ======================================================================
#   Loss:       nan
#   MAE:        0.2167
#   RMSE:       0.2646
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9583  [███████████████████░]
#   SRCC:       0.9511  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.21665397100664277, 'mse': 0.07000376852677301, 'rmse': 0.26458225285678744, 'plcc': 0.9582898944410304, 'srcc': 0.9511071327643235}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.76
# ======================================================================
#   Loss:       nan
#   MAE:        0.2167
#   RMSE:       0.2646
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9583  [███████████████████░]
#   SRCC:       0.9511  [███████████████████░]
# ======================================================================
#
# Epoch 1.82 | Loss: 75148579.8400
# Epoch 1.82 | Loss: 75148579.8400
# Epoch 1.87 | Loss: 59613260.8000
# Epoch 1.87 | Loss: 59613260.8000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.17544001857023245, 'mse': 0.049641539241860363, 'rmse': 0.2228038133467656, 'plcc': 0.9582430895658991, 'srcc': 0.9515252801135982}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.87
# ======================================================================
#   Loss:       nan
#   MAE:        0.1754
#   RMSE:       0.2228
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9582  [███████████████████░]
#   SRCC:       0.9515  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.17544001857023245, 'mse': 0.049641539241860363, 'rmse': 0.2228038133467656, 'plcc': 0.9582430895658991, 'srcc': 0.9515252801135982}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.87
# ======================================================================
#   Loss:       nan
#   MAE:        0.1754
#   RMSE:       0.2228
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9582  [███████████████████░]
#   SRCC:       0.9515  [███████████████████░]
# ======================================================================
#
# Epoch 1.93 | Loss: 17891214.0800
# Epoch 1.93 | Loss: 17891214.0800
# Epoch 1.99 | Loss: 46143201.2800
# Epoch 1.99 | Loss: 46143201.2800
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18543047215882022, 'mse': 0.05317031426563568, 'rmse': 0.23058689092321724, 'plcc': 0.9596295274469503, 'srcc': 0.950490320790357}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.99
# ======================================================================
#   Loss:       nan
#   MAE:        0.1854
#   RMSE:       0.2306
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9596  [███████████████████░]
#   SRCC:       0.9505  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18543047215882022, 'mse': 0.05317031426563568, 'rmse': 0.23058689092321724, 'plcc': 0.9596295274469503, 'srcc': 0.950490320790357}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 1.99
# ======================================================================
#   Loss:       nan
#   MAE:        0.1854
#   RMSE:       0.2306
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9596  [███████████████████░]
#   SRCC:       0.9505  [███████████████████░]
# ======================================================================
#
# Epoch 2.04 | Loss: 11448.6763
# Epoch 2.04 | Loss: 11448.6763
# Epoch 2.09 | Loss: 6560.3663
# Epoch 2.09 | Loss: 6560.3663
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1919918866428432, 'mse': 0.057623616269672294, 'rmse': 0.2400491955197357, 'plcc': 0.9609742989245268, 'srcc': 0.951853509330488}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.09
# ======================================================================
#   Loss:       nan
#   MAE:        0.1920
#   RMSE:       0.2400
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9610  [███████████████████░]
#   SRCC:       0.9519  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.1919918866428432, 'mse': 0.057623616269672294, 'rmse': 0.2400491955197357, 'plcc': 0.9609742989245268, 'srcc': 0.951853509330488}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.09
# ======================================================================
#   Loss:       nan
#   MAE:        0.1920
#   RMSE:       0.2400
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9610  [███████████████████░]
#   SRCC:       0.9519  [███████████████████░]
# ======================================================================
#
# Epoch 2.15 | Loss: 47481088.0000
# Epoch 2.15 | Loss: 47481088.0000
# Epoch 2.21 | Loss: 401007.0000
# Epoch 2.21 | Loss: 401007.0000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.16892473775250308, 'mse': 0.046420400939953824, 'rmse': 0.21545394157442055, 'plcc': 0.9593075435488221, 'srcc': 0.9506311970856809}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.21
# ======================================================================
#   Loss:       nan
#   MAE:        0.1689
#   RMSE:       0.2155
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9593  [███████████████████░]
#   SRCC:       0.9506  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.16892473775250308, 'mse': 0.046420400939953824, 'rmse': 0.21545394157442055, 'plcc': 0.9593075435488221, 'srcc': 0.9506311970856809}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.21
# ======================================================================
#   Loss:       nan
#   MAE:        0.1689
#   RMSE:       0.2155
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9593  [███████████████████░]
#   SRCC:       0.9506  [███████████████████░]
# ======================================================================
#
# Epoch 2.26 | Loss: 3384045.1200
# Epoch 2.26 | Loss: 3384045.1200
# Epoch 2.32 | Loss: 5939954.5600
# Epoch 2.32 | Loss: 5939954.5600
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.19183275585206122, 'mse': 0.057608187556743407, 'rmse': 0.24001705680376845, 'plcc': 0.9565256236289028, 'srcc': 0.95167168917175}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.32
# ======================================================================
#   Loss:       nan
#   MAE:        0.1918
#   RMSE:       0.2400
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9565  [███████████████████░]
#   SRCC:       0.9517  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.19183275585206122, 'mse': 0.057608187556743407, 'rmse': 0.24001705680376845, 'plcc': 0.9565256236289028, 'srcc': 0.95167168917175}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.32
# ======================================================================
#   Loss:       nan
#   MAE:        0.1918
#   RMSE:       0.2400
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9565  [███████████████████░]
#   SRCC:       0.9517  [███████████████████░]
# ======================================================================
#
# Epoch 2.37 | Loss: 62261703.6800
# Epoch 2.37 | Loss: 62261703.6800
# Epoch 2.43 | Loss: 39372.6200
# Epoch 2.43 | Loss: 39372.6200
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18682345657538, 'mse': 0.054544635135856556, 'rmse': 0.23354792899072463, 'plcc': 0.9591991684807502, 'srcc': 0.9517784299622741}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.43
# ======================================================================
#   Loss:       nan
#   MAE:        0.1868
#   RMSE:       0.2335
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9592  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18682345657538, 'mse': 0.054544635135856556, 'rmse': 0.23354792899072463, 'plcc': 0.9591991684807502, 'srcc': 0.9517784299622741}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.43
# ======================================================================
#   Loss:       nan
#   MAE:        0.1868
#   RMSE:       0.2335
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9592  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
# Epoch 2.48 | Loss: 17595128.3200
# Epoch 2.48 | Loss: 17595128.3200
# Epoch 2.54 | Loss: 135894210.5600
# Epoch 2.54 | Loss: 135894210.5600
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18789291579093448, 'mse': 0.05462207716706507, 'rmse': 0.23371366491299791, 'plcc': 0.9607255257771327, 'srcc': 0.951282764624658}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.54
# ======================================================================
#   Loss:       nan
#   MAE:        0.1879
#   RMSE:       0.2337
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9607  [███████████████████░]
#   SRCC:       0.9513  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18789291579093448, 'mse': 0.05462207716706507, 'rmse': 0.23371366491299791, 'plcc': 0.9607255257771327, 'srcc': 0.951282764624658}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.54
# ======================================================================
#   Loss:       nan
#   MAE:        0.1879
#   RMSE:       0.2337
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9607  [███████████████████░]
#   SRCC:       0.9513  [███████████████████░]
# ======================================================================
#
# Epoch 2.59 | Loss: 29903936.0000
# Epoch 2.59 | Loss: 29903936.0000
# Epoch 2.65 | Loss: 270.9274
# Epoch 2.65 | Loss: 270.9274
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18986744369121789, 'mse': 0.055395562372143256, 'rmse': 0.23536261889293988, 'plcc': 0.9612213695245772, 'srcc': 0.9517172056923721}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.65
# ======================================================================
#   Loss:       nan
#   MAE:        0.1899
#   RMSE:       0.2354
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9612  [███████████████████░]
#   SRCC:       0.9517  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18986744369121789, 'mse': 0.055395562372143256, 'rmse': 0.23536261889293988, 'plcc': 0.9612213695245772, 'srcc': 0.9517172056923721}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.65
# ======================================================================
#   Loss:       nan
#   MAE:        0.1899
#   RMSE:       0.2354
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9612  [███████████████████░]
#   SRCC:       0.9517  [███████████████████░]
# ======================================================================
#
# Epoch 2.70 | Loss: 146244454.4000
# Epoch 2.70 | Loss: 146244454.4000
# Epoch 2.76 | Loss: 2260695.8400
# Epoch 2.76 | Loss: 2260695.8400
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18533601546511094, 'mse': 0.05309358050070523, 'rmse': 0.23042044288800687, 'plcc': 0.9601322232649405, 'srcc': 0.9517715541422445}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.76
# ======================================================================
#   Loss:       nan
#   MAE:        0.1853
#   RMSE:       0.2304
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9601  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18533601546511094, 'mse': 0.05309358050070523, 'rmse': 0.23042044288800687, 'plcc': 0.9601322232649405, 'srcc': 0.9517715541422445}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.76
# ======================================================================
#   Loss:       nan
#   MAE:        0.1853
#   RMSE:       0.2304
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9601  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
# Epoch 2.81 | Loss: 330999.2000
# Epoch 2.81 | Loss: 330999.2000
# Epoch 2.87 | Loss: 3246790.4000
# Epoch 2.87 | Loss: 3246790.4000
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18822882264868962, 'mse': 0.054850101435349734, 'rmse': 0.23420098512890533, 'plcc': 0.9605263351972999, 'srcc': 0.9521181092606711}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.87
# ======================================================================
#   Loss:       nan
#   MAE:        0.1882
#   RMSE:       0.2342
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9605  [███████████████████░]
#   SRCC:       0.9521  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18822882264868962, 'mse': 0.054850101435349734, 'rmse': 0.23420098512890533, 'plcc': 0.9605263351972999, 'srcc': 0.9521181092606711}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.87
# ======================================================================
#   Loss:       nan
#   MAE:        0.1882
#   RMSE:       0.2342
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9605  [███████████████████░]
#   SRCC:       0.9521  [███████████████████░]
# ======================================================================
#
# Epoch 2.92 | Loss: 1970539.2000
# Epoch 2.92 | Loss: 1970539.2000
# Epoch 2.98 | Loss: 57590.1700
# Epoch 2.98 | Loss: 57590.1700
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18625834115749554, 'mse': 0.053706288014327364, 'rmse': 0.23174617152032387, 'plcc': 0.9607738460565626, 'srcc': 0.9518089255246935}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.98
# ======================================================================
#   Loss:       nan
#   MAE:        0.1863
#   RMSE:       0.2317
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9608  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
#
# [DEBUG] Collected 1813 predictions
# [DEBUG] Computing metrics: pred shape=(1813,), gt shape=(1813,)
# [DEBUG] Computed metrics: {'mae': 0.18625834115749554, 'mse': 0.053706288014327364, 'rmse': 0.23174617152032387, 'plcc': 0.9607738460565626, 'srcc': 0.9518089255246935}
# [DEBUG] Added metrics to output.metrics: ['eval_mae', 'eval_mse', 'eval_rmse', 'eval_plcc', 'eval_srcc']
#
# ======================================================================
# 📊 Validation Results at Epoch 2.98
# ======================================================================
#   Loss:       nan
#   MAE:        0.1863
#   RMSE:       0.2317
#   ------------------------------------------------------------------
#   Correlation Metrics:
#   PLCC:       0.9608  [███████████████████░]
#   SRCC:       0.9518  [███████████████████░]
# ======================================================================
#
# ================================================================================
#
# ✅ Quality training completed!
#
# 📊 Generating training curves...
# ================================================================================
#
# ✅ Quality training completed!
#
# 📊 Generating training curves...
#
# 📊 Training curves saved to: outputs/10270900/03_quality/training_curves.png
#
# 📊 Training curves saved to: outputs/10270900/03_quality/training_curves.png
# 📊 Training curves (PDF) saved to: outputs/10270900/03_quality/training_curves.pdf
# 📊 Training curves (PDF) saved to: outputs/10270900/03_quality/training_curves.pdf
# 📊 Metrics summary saved to: outputs/10270900/03_quality/metrics_summary.png
# ⚠️  No correlation metrics (PLCC/SRCC) found in TensorBoard logs
# ✅ All plots saved!
# ✅ Plots saved to outputs/10270900/03_quality/
# 📊 Metrics summary saved to: outputs/10270900/03_quality/metrics_summary.png
# ⚠️  No correlation metrics (PLCC/SRCC) found in TensorBoard logs
# ✅ All plots saved!
# ✅ Plots saved to outputs/10270900/03_quality/

# %% [markdown]
# ---
# ## Save Final Model

# %%
print("="*80)
print("SAVING FINAL MODEL")
print("="*80)

final_path = f"{OUTPUT_DIR}/final_model"
model.model.save_pretrained(final_path)
tokenizer.save_pretrained(final_path)

print(f"✅ Final model saved to: {final_path}")
print("\n" + "="*80)
print("🎉 SEQUENTIAL TRAINING PIPELINE COMPLETED!")
print("="*80)
print(f"\n📊 Results:")
print(f"  Stage 1 (Scene):      {output_dir_scene}/")
print(f"  Stage 2 (Distortion): {output_dir_distortion}/")
print(f"  Stage 3 (Quality):    {output_dir_quality}/")
print(f"  Final Model:          {final_path}/")
print()
# Out:
# ================================================================================
# SAVING FINAL MODEL
# ================================================================================
# ✅ Final model saved to: outputs/10270900/final_model
#
# ================================================================================
# 🎉 SEQUENTIAL TRAINING PIPELINE COMPLETED!
# ================================================================================
#
# 📊 Results:
#   Stage 1 (Scene):      outputs/10270900/01_scene/
#   Stage 2 (Distortion): outputs/10270900/02_distortion/
#   Stage 3 (Quality):    outputs/10270900/03_quality/
#   Final Model:          outputs/10270900/final_model/
#
# ✅ Final model saved to: outputs/10270900/final_model
#
# ================================================================================
# 🎉 SEQUENTIAL TRAINING PIPELINE COMPLETED!
# ================================================================================
#
# 📊 Results:
#   Stage 1 (Scene):      outputs/10270900/01_scene/
#   Stage 2 (Distortion): outputs/10270900/02_distortion/
#   Stage 3 (Quality):    outputs/10270900/03_quality/
#   Final Model:          outputs/10270900/final_model/

# %% [markdown]
# ---
# ## Evaluation (Optional)
#
# Evaluate the final model on test set

# %%
# You can evaluate on test set here if needed
# Example:
# test_dataset = IQAPairDataset(
#     dataset_paths=dataset_paths,
#     processor=processor,
#     tokenizer=tokenizer,
#     split="testing",
# )
# 
# test_results = trainer_quality.evaluate(test_dataset)
# print(test_results)

print("💡 To evaluate the model, use the eval_sequential_model.py script:")
print(f"   python eval_sequential_model.py --model_path {final_path} --dataset_paths {' '.join(DATASET_PATHS)} --split testing")
# Out:
# 💡 To evaluate the model, use the eval_sequential_model.py script:
#    python eval_sequential_model.py --model_path outputs/10270900/final_model --dataset_paths datasets/koniq-10k/ --split testing
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
